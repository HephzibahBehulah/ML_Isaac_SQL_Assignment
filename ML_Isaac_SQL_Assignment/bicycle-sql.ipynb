# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#   Isaac Oluwole Adigun
# </p>

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#   SQL Bicycle Store Analysis ( ML ReDI 2025 )
# </p>

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Read in CSV files
brands = pd.read_csv('brands.csv')
categories = pd.read_csv('categories.csv')
customers = pd.read_csv('customers.csv')
order_items = pd.read_csv('order_items.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')
staffs = pd.read_csv('staffs.csv')
stocks = pd.read_csv('stocks.csv')
stores = pd.read_csv('stores.csv')

# Create database connection
connection = sqlite3.connect('bike_store.db')

# Insert data into database
brands.to_sql('brands', connection, if_exists='replace', index=False)
categories.to_sql('categories', connection, if_exists='replace', index=False)
customers.to_sql('customers', connection, if_exists='replace', index=False)
order_items.to_sql('order_items', connection, if_exists='replace', index=False)
orders.to_sql('orders', connection, if_exists='replace', index=False)
products.to_sql('products', connection, if_exists='replace', index=False)
staffs.to_sql('staffs', connection, if_exists='replace', index=False)
stocks.to_sql('stocks', connection, if_exists='replace', index=False)
stores.to_sql('stores', connection, if_exists='replace', index=False)

# %% [markdown]
# ![image.png](attachment:b5cb749f-60a3-4933-ae98-ec7ee484c006.png)![image.png](attachment:e0eaa96f-81c8-4714-9411-e40582180cc2.png)

# %% [markdown]
# ***1. Built Functions***

# %%
# Select all tables
display(brands)
display(categories)
display(customers)
display(order_items)
display(orders)
display(products)
display(staffs)
display(stocks)
display(stores)
# Out:
#    brand_id    brand_name
# 0         1       Electra
# 1         2          Haro
# 2         3        Heller
# 3         4   Pure Cycles
# 4         5       Ritchey
# 5         6       Strider
# 6         7  Sun Bicycles
# 7         8         Surly
# 8         9          Trek
#    category_id        category_name
# 0            1    Children Bicycles
# 1            2     Comfort Bicycles
# 2            3    Cruisers Bicycles
# 3            4  Cyclocross Bicycles
# 4            5       Electric Bikes
# 5            6       Mountain Bikes
# 6            7           Road Bikes
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks             NaN
# 1               2       Kasha      Todd             NaN
# 2               3      Tameka    Fisher             NaN
# 3               4       Daryl    Spence             NaN
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# ...

# %%
# return all columns and records from the stores table 
query = """
SELECT 
    * 
FROM 
    stores;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return all columns and records from the orders table 
query = """
SELECT 
    * 
FROM 
    orders;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# Select first 5 records of the orders table ordered by the order_date ascending
query = """
SELECT 
    *
FROM 
    orders
ORDER BY 
    order_date ASC
LIMIT 5;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return all columns and records from the products table 
query = """
SELECT 
    *
FROM 
    products
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return all records where product_name contains "Frameset" somewhere 
query = """
SELECT 
    *
FROM 
    products
WHERE
    product_name LIKE '%Frameset%'
"""

df = pd.read_sql_query(query, connection)
df

# %%
# pull up Jamaal Morrison's customer record
query = """
SELECT 
    *
FROM 
    customers
WHERE
    last_name = 'Morrison'
AND
    first_name = 'Jamaal';
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return 5 records where city is either Brooklyn or Staten Island
query = """
SELECT 
    *
FROM 
    customers
WHERE
    city IN ('Brooklyn', 'Staten Island')
LIMIT 5;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return 5 records where state is either TX or CA and phone is not null
query = """
SELECT 
    *
FROM 
    customers
WHERE
    state IN ('TX', 'CA')
AND
    phone IS NOT NULL
LIMIT 5;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return entire record of the maximum list price aliased as max_list_price
query = """
SELECT 
    *,
    MAX(list_price) AS max_list_price
FROM 
    order_items;
"""

df = pd.read_sql_query(query, connection)
df

# %%
# return daily order counts
query = """
SELECT 
    order_date, COUNT(order_id) AS order_count
FROM 
    orders
GROUP BY
    order_date
"""

df = pd.read_sql_query(query, connection)

df

# %%
# Built in Functions
def get_store_orders(store_id):
    query = f"""
    SELECT 
        *
    FROM 
        orders
    WHERE
        store_id = {store_id};
    """
    df = pd.read_sql_query(query, connection)
    return df
df
# Out:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03
# 3         4          175             4  2016-01-03    2016-01-04   2016-01-05
# 4         5         1324             4  2016-01-03    2016-01-06   2016-01-06
#
#    store_id  staff_id  store_id        store_name           phone  \
# 0         1         2         1  Santa Cruz Bikes  (831) 476-4321
# 1         2         6         2     Baldwin Bikes  (516) 379-8888
# 2         2         7         2     Baldwin Bikes  (516) 379-8888
# 3         1         3         1  Santa Cruz Bikes  (831) 476-4321
# 4         2         6         2     Baldwin Bikes  (516) 379-8888
#
#                   email              street        city state  zip_code
# ...

# %% [markdown]
# ***2. Basic Joins***

# %%
# join orders and customers to get order counts by state
query = """
SELECT
    customers.state, COUNT(orders.order_id) AS order_count
FROM
    orders
INNER JOIN
    customers
ON
    orders.customer_id = customers.customer_id
GROUP BY
    customers.state
"""
df = pd.read_sql_query(query, connection)
df

# %%
# return the first 5 records of the inner-join of tables orders and stores on key store_id
query = """
SELECT 
    *
FROM 
    orders
INNER JOIN
    stores
ON
    orders.store_id = stores.store_id
LIMIT 5;
"""

df = pd.read_sql_query(query, connection)
df
# Out:
#    order_id  customer_id  order_status  order_date required_date shipped_date  \
# 0         1          259             4  2016-01-01    2016-01-03   2016-01-03
# 1         2         1212             4  2016-01-01    2016-01-04   2016-01-03
# 2         3          523             4  2016-01-02    2016-01-05   2016-01-03
# 3         4          175             4  2016-01-03    2016-01-04   2016-01-05
# 4         5         1324             4  2016-01-03    2016-01-06   2016-01-06
#
#    store_id  staff_id  store_id        store_name           phone  \
# 0         1         2         1  Santa Cruz Bikes  (831) 476-4321
# 1         2         6         2     Baldwin Bikes  (516) 379-8888
# 2         2         7         2     Baldwin Bikes  (516) 379-8888
# 3         1         3         1  Santa Cruz Bikes  (831) 476-4321
# 4         2         6         2     Baldwin Bikes  (516) 379-8888
#
#                   email              street        city state  zip_code
# ...

# %%
# left join orders and staffs to get all orders with staff info
query = """
SELECT
    *
FROM
    orders
LEFT JOIN
    staffs
ON
    orders.staff_id = staffs.staff_id
"""
df = pd.read_sql_query(query, connection)
df
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# 1613      1614          135             3  2018-11-28    2018-11-28
# 1614      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id  staff_id first_name last_name  \
# 0      2016-01-03         1         2         2     Mireya  Copeland
# ...

# %%
# combine orders, customers, and stores to get order counts by customer state and store city
query = """
SELECT
    customers.state, stores.city, COUNT(orders.order_id) AS order_count
FROM
    orders
INNER JOIN
    customers
ON
    orders.customer_id = customers.customer_id
INNER JOIN
    stores
ON
    orders.store_id = stores.store_id
GROUP BY
    customers.state, stores.city
"""
df = pd.read_sql_query(query, connection)
df
# Out:
#   state        city  order_count
# 0    CA  Santa Cruz          348
# 1    NY     Baldwin         1093
# 2    TX     Rowlett          174

# %% [markdown]
# ***3. Nested Queries***

# %%
# Nested Queries
query = """
SELECT
    *
FROM
    orders
WHERE
    store_id = (
        SELECT
            store_id
        FROM
            stores
        WHERE
            store_name = 'Downtown Bike Shop'
    );
"""
df = pd.read_sql_query(query, connection)
df

# %% [markdown]
# ***4. With Clause***

# %%
# With clause
query = """
WITH StoreOrders AS (
        SELECT
            *
        FROM
            orders
        WHERE
            store_id = (
                SELECT
                    store_id
                FROM
                    stores
                WHERE
                    store_name = 'Santa Cruz Bikes'
            )
    )
    SELECT
        *
    FROM
        StoreOrders;
    """
df = pd.read_sql_query(query, connection)
df
# Out:
#      order_id  customer_id  order_status  order_date required_date  \
# 0           1          259             4  2016-01-01    2016-01-03
# 1           4          175             4  2016-01-03    2016-01-04
# 2           9           60             4  2016-01-05    2016-01-08
# 3          12           91             4  2016-01-06    2016-01-08
# 4          14          258             4  2016-01-09    2016-01-11
# ..        ...          ...           ...         ...           ...
# 343      1591          165             2  2018-04-27    2018-04-27
# 344      1598          239             2  2018-04-29    2018-04-29
# 345      1607           33             3  2018-07-11    2018-07-11
# 346      1608           53             3  2018-07-12    2018-07-12
# 347      1612            3             3  2018-10-21    2018-10-21
#
#     shipped_date  store_id  staff_id
# 0     2016-01-03         1         2
# 1     2016-01-05         1         3
# 2     2016-01-08         1         2
# ...

# %% [markdown]
# ***5. Data Integrity***

# %%
# Data Integrity - get foreign key list for orders without overwriting the main `df`
query = "PRAGMA foreign_key_list(orders);"
fk_df = pd.read_sql_query(query, connection)

# show result (will be empty if there are no foreign keys)
if fk_df.empty:
	print("No foreign keys found for table 'orders'.")
else:
	fk_df
# Out:
# No foreign keys found for table 'orders'.

# %% [markdown]
# <p style="background: linear-gradient(90deg, #fbc2eb, #a6c1ee);
#          font-family: 'Montserrat', sans-serif;
#          font-size: 24px;
#          text-align: center;
#          color: #1f1f1f;
#          padding: 22px 42px;
#          border-radius: 30px;
#          border: 3px solid #8fa6dc;
#          box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#          letter-spacing: 1.1px;
#          word-spacing: 4px;
#          font-weight: 700;
#          text-shadow: 1px 1px 2px rgba(0,0,0,0.08);
#          margin: 10px 0 18px;">
#   Thankn you und Vielen Dank
# </p>
